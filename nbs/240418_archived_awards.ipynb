# %% [markdown]
# ### Check Archived Opportunities for `Analytic Assessment Support`

# %% [markdown]
# I'm trying to find any information that I can surrounding the previous winner of this contract, and how fed. procurement handles recurring contracts.`

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./data/cleaned_FY2023_archived_opportunities.csv")
df.head()
# Out:
#                          Unnamed: 0  \
# 0  1197781f02574d8eba56efda3e7a62a9
# 1  435547939cdd4c60aebf0ee8d5f10fde
# 2  2d374acf8b76470796d9696ef4899267
# 3  907ea8a3feea4c9ca36e1db001619106
# 4  df23e167a30c4a659551013a05c9f10a
#
#                                            NoticeId          Title  \
# 0          30 SFS Cold Weather Gear- Vandenberg SFB             CA
# 1      SecureView Tech Refresh Desktop Workstations  FA521523Q00SV
# 2  Vandenberg 532 Commercial Internet/WIFI Services  FA461023P0105
# 3                               Renovate Bryan Hall         FA3010
# 4                    Antiterrorism Support Services  HQ003423C0143
#
#               Sol# Department/Ind.Agency  \
# 0    FA461023P0125       DEPT OF DEFENSE
# 1  DEPT OF DEFENSE                   057
# 2  DEPT OF DEFENSE                   057
# 3  DEPT OF DEFENSE                   057
# 4  DEPT OF DEFENSE                   097
#
#                                      CGAC               Sub-Tier  \
# 0                                     057  DEPT OF THE AIR FORCE
# 1                   DEPT OF THE AIR FORCE                   5700
# 2                   DEPT OF THE AIR FORCE                   5700
# 3                   DEPT OF THE AIR FORCE                   5700
# 4  WASHINGTON HEADQUARTERS SERVICES (WHS)                   97F5
#
#                           FPDS Code              Office  \
# 0                              5700  FA4610  30 CONS PK
# 1               FA5215  766 ESS PKP              FA5215
# 2                FA4610  30 CONS PK              FA4610
# 3                FA3010  81 CONS CC              FA3010
# 4  WASHINGTON HEADQUARTERS SERVICES              HQ0034
#
#                      AAC Code  ... SecondaryContactPhone SecondaryContactFax  \
# 0                      FA4610  ...                   NaN                 NaN
# 1  2023-09-30 21:31:26.359-04  ...                   NaN              OFFICE
# 2  2023-09-30 20:38:13.619-04  ...          805-606-4469                 NaN
# 3  2023-09-30 20:27:28.931-04  ...            2283771839                 NaN
# 4  2023-09-30 20:05:00.737-04  ...                   NaN              OFFICE
#
#   OrganizationType       State            City     ZipCode CountryCode  \
# 0           OFFICE          CA  VANDENBERG SFB  93437-5212         USA
# 1               HI       JBPHH      96860-4928         USA         NaN
# 2           OFFICE          CA  VANDENBERG SFB  93437-5212         USA
# 3           OFFICE          MS     KEESLER AFB  39534-2701         USA
# 4               DC  WASHINGTON       203011000         USA         NaN
#
#                                   AdditionalInfoLink  \
# 0                                                NaN
# 1  https://sam.gov/opp/435547939cdd4c60aebf0ee8d5...
# 2                                                NaN
# 3                                                NaN
# 4  https://sam.gov/opp/df23e167a30c4a659551013a05...
#
#                                                 Link  \
# 0  https://sam.gov/opp/1197781f02574d8eba56efda3e...
# 1  This is a combined synopsis/solicitation for R...
# 2  https://sam.gov/opp/2d374acf8b76470796d9696ef4...
# 3  https://sam.gov/opp/907ea8a3feea4c9ca36e1db001...
# 4                     This is Firm Fixed Price (FFP)
#
#                                          Description
# 0                                                NaN
# 1   Saturday 30 Sep 2023 by 6:00PM Hawaii Standar...
# 2                                                NaN
# 3                                                NaN
# 4                             8(a) sole source award
#
# [5 rows x 48 columns]
